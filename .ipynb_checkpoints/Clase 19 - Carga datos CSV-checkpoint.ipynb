# %%
import pandas as pd

# %%
pd.read_csv("C:/Users/fgarc/proyectos Python/Curso Machine Learning Udemy/Data/diabetes_data_upload.csv", 
            sep =",",
            header="infer", ## probar a poner a 0 y darle nuevos nombres a las columnas con atributo names=["col1",...]
            skiprows=[3,5], ## probar con range
            nrows=20,
           )
# Out:
#     Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0    40   Male       No        Yes                 No      Yes         No
# 1    58   Male       No         No                 No      Yes         No
# 2    45   Male       No         No                Yes      Yes        Yes
# 3    55   Male      Yes        Yes                 No      Yes        Yes
# 4    57   Male      Yes        Yes                 No      Yes        Yes
# 5    66   Male      Yes        Yes                Yes      Yes         No
# 6    67   Male      Yes        Yes                 No      Yes        Yes
# 7    70   Male       No        Yes                Yes      Yes        Yes
# 8    44   Male      Yes        Yes                 No      Yes         No
# 9    38   Male      Yes        Yes                 No       No        Yes
# 10   35   Male      Yes         No                 No       No        Yes
# 11   61   Male      Yes        Yes                Yes      Yes        Yes
# ...

# %%
pd.read_csv("C:/Users/fgarc/proyectos Python/Curso Machine Learning Udemy/Data/diabetes_data_upload.csv", 
            sep =",",
            header=0,# probar a poner a 0 y darle nuevos nombres a las columnas con atributo names=["col1",...]
            names=["col1","col2","col3","col4","col5","col6","col7","col8","col9","col10","col11","col12","col13","col14","col15","col16","col17"],
            skiprows=range(3,7), ## probar con range
            nrows=20,
           )
# Out:
#     col1  col2 col3 col4 col5 col6 col7 col8 col9 col10 col11 col12 col13  \
# 0     40  Male   No  Yes   No  Yes   No   No   No   Yes    No   Yes    No
# 1     58  Male   No   No   No  Yes   No   No  Yes    No    No    No   Yes
# 2     57  Male  Yes  Yes   No  Yes  Yes  Yes   No    No    No   Yes   Yes
# 3     66  Male  Yes  Yes  Yes  Yes   No   No  Yes   Yes   Yes    No   Yes
# 4     67  Male  Yes  Yes   No  Yes  Yes  Yes   No   Yes   Yes    No   Yes
# 5     70  Male   No  Yes  Yes  Yes  Yes   No  Yes   Yes   Yes    No    No
# 6     44  Male  Yes  Yes   No  Yes   No  Yes   No    No   Yes   Yes    No
# 7     38  Male  Yes  Yes   No   No  Yes  Yes   No   Yes    No   Yes    No
# 8     35  Male  Yes   No   No   No  Yes  Yes   No    No   Yes   Yes    No
# 9     61  Male  Yes  Yes  Yes  Yes  Yes  Yes  Yes   Yes    No    No    No
# 10    60  Male  Yes  Yes   No  Yes  Yes   No  Yes   Yes    No   Yes   Yes
# 11    58  Male  Yes  Yes   No  Yes  Yes   No   No    No    No   Yes   Yes
# ...
