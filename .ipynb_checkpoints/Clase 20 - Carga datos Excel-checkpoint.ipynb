# %%
import pandas as pd

# %%
datos = pd.read_excel(io ="C:/Users/fgarc/proyectos Python/Curso Machine Learning Udemy/Data/activaciones_samur_2020.xlsx",
             sheet_name=0,## selecciona las hojas del excel a cargar, no necesario xq 0 es el valor x defecto
             header=0,##selecciona la fila con el nombre de las columnas, no necesario xq 0 es el valor x defecto
             nrows=50)
datos
# Out:
#      Año    Mes Hora Solicitud Hora Intervención  \
# 0   2020  ENERO       00:03:21          00:08:49
# 1   2020  ENERO       00:04:03          00:14:44
# 2   2020  ENERO       00:04:05          00:10:12
# 3   2020  ENERO       00:05:09          00:13:15
# 4   2020  ENERO       00:07:43          00:16:19
# 5   2020  ENERO       00:17:50          00:23:58
# 6   2020  ENERO       00:24:11          00:28:35
# 7   2020  ENERO       00:26:28          00:35:09
# 8   2020  ENERO       00:37:46               NaN
# 9   2020  ENERO       00:38:53          00:46:15
# 10  2020  ENERO       00:39:00          00:46:10
# 11  2020  ENERO       00:46:11          00:56:11
# 12  2020  ENERO       00:46:14          00:51:11
# 13  2020  ENERO       00:47:40          00:55:50
# 14  2020  ENERO       00:47:55          00:56:58
# 15  2020  ENERO       01:00:54               NaN
# 16  2020  ENERO       01:01:10          01:13:56
# 17  2020  ENERO       01:01:39          01:05:04
# ...

# %%
datos.dtypes
# Out:
# Año                   int64
# Mes                  object
# Hora Solicitud       object
# Hora Intervención    object
# Código               object
# Distrito             object
# Hospital             object
# dtype: object
